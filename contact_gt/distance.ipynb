# %% [markdown]
# # Distance Computation
#
# A script to compute the distance from each hand-joint to the object, based on the pose data.
#
#
# #### Notes
#
# Input:
#
# - Hand Pose: 1 (annotate?) + $21*3$ (x,y,z in order) (left hand) + 1 + $21*3$ (right hand)
# - Object Pose: 1 (object class) + $21*3$ (x,y,z in order) bounding box (1 center, 8 corners, 12 mid-edge)
#
# Output:
#
# - Distance map: 21 (left hand) + 21 (right hand) distances from joints
#
# ----

# %% [markdown]
# Imports

# %%
import os
import numpy as np
from numpy.typing import NDArray
import tqdm
from typing import List

# %% [markdown]
# Parameters

# %%
n_frames_per_seq : int = 8
mode = 'train' # 'train' , 'val' , 'test'
h2o_root = '../data/h2o/'
sample_root = h2o_root + f'seq_{n_frames_per_seq}_{mode}/'

# %% [markdown]
# ### Data Format Helpers

# %%
def format_hand_poses(hand_poses: NDArray) -> NDArray:
    """
    Format the raw hand_poses vector into a 21x3 matrix for each hand

    Args:
    -----
    hand_poses: NDArray (128,)
        Raw hand poses vector

    Returns:
    --------
    hand_poses_left: NDArray (21, 3)
        Hand poses matrix for left hand
    hand_poses_right: NDArray (21, 3)
        Hand poses matrix for right hand
    """
    assert hand_poses.shape == (128,), f"hand_poses should be of shape (128,) but got {hand_poses.shape}"

    hand_poses_left = hand_poses[1:64].reshape((21, 3))
    hand_poses_right = hand_poses[65:].reshape((21, 3))

    return hand_poses_left, hand_poses_right

# %%
def format_object_poses(obj_poses: NDArray) -> List[NDArray]:
    """
    Format and group the raw obj_poses vector into a list of the poses.

    The list has 3 elements:
    1. (3,)   NDArray of the object's center pose
    2. (8,3)  NDArray of the object's corner vertices
    3. (12,3) NDArray of the object's mid-edge vertices

    Args:
    -----
    obj_poses: NDArray (64,)
        Raw object poses vector

    Returns:
    --------
    obj_poses_list: List[NDArray]
        List of grouped object poses
    """
    assert obj_poses.shape == (64,), f"obj_poses should be of shape (64,) but got {obj_poses.shape}"

    obj_center = obj_poses[1:4]
    obj_corners = obj_poses[4:28].reshape((8, 3))
    obj_edges = obj_poses[28:].reshape((12, 3))

    return [obj_center, obj_corners, obj_edges]

# %% [markdown]
# ### Transformation Helpers

# %%
def invert_transformation_matrix(T: NDArray) -> NDArray:
    """
    Invert the transformation matrix T

    Args:
    -----
    T: NDArray (4, 4)
        Transformation matrix

    Returns:
    --------
    T_inv: NDArray (4, 4)
        Inverted transformation matrix
    """
    assert T.shape == (4, 4), f"T should be of shape (4, 4) but got {T.shape}"

    R = T[:3, :3]
    t = T[:3, 3]
    T_inv = np.eye(4)
    T_inv[:3, :3] = R.T
    T_inv[:3, 3] = -R.T @ t

    return T_inv

# %%
def to_hom_3D(points: NDArray) -> NDArray:
    """
    Convert the input points to homogeneous coordinates.

    Args:
    -----
    points: NDArray (N, 3)
        Input points
    
    Returns:
    --------
    points_hom: NDArray (N, 4)
        Homogeneous coordinates of the input points
    """
    assert points.shape[1] == 3, f"points should be of shape (N, 3) but got {points.shape}"
    return np.hstack((points, np.ones((points.shape[0], 1))))

# %%
def to_cart_3D(points_hom: NDArray) -> NDArray:
    """
    Convert the input points in homogeneous coordinates to cartesian coordinates.

    Args:
    -----
    points_hom: NDArray (N, 4)
        Input points in homogeneous coordinates
    
    Returns:
    --------
    points: NDArray (N, 3)
        Cartesian coordinates of the input points
    """
    assert points_hom.shape[1] == 4, f"points_hom should be of shape (N, 4) but got {points_hom.shape}"
    return points_hom[:, :3] / points_hom[:, 3, None]

# %%
def transfrom_pts(pts_hom: NDArray, T: NDArray) -> NDArray:
    """
    Transform the input points using the input transformation matrix.

    Args:
    -----
    pts_hom: NDArray (N, 4)
        Input points in homogeneous coordinates
    T: NDArray (4, 4)
        Transformation matrix
    
    Returns:
    --------
    pts_transformed_hom: NDArray (N, 4)
        Transformed points in homogeneous coordinates
    """
    assert pts_hom.shape[1] == 4, f"pts should be of shape (N, 4) but got {pts_hom.shape}"
    assert T.shape == (4, 4), f"T should be of shape (4, 4) but got {T.shape}"

    return np.dot(T, pts_hom.T).T

# %%
def assert_box_transform(T_OC: NDArray, C_obj_center: NDArray):
    """
    Asserts the transformation from the camera to the object frame is correct.

    Args:
    -----
    T_OC: NDArray (4, 4)
        Transformation matrix from the camera to the object frame
    C_obj_center: NDArray (3,)
        Object's center in the camera frame
    """
    assert T_OC.shape == (4, 4), f"T_OC should be of shape (4, 4) but got {T_OC.shape}"
    assert C_obj_center.shape == (3,), f"C_obj_center should be of shape (3,) but got {C_obj_center.shape}"

    O_obj_center = transfrom_pts(to_hom_3D(C_obj_center[np.newaxis, :]), T_OC)
    # assert this is close to [0, 0, 0, 1]
    assert np.allclose(O_obj_center, np.array([[0, 0, 0, 1]]), atol=1e-6), \
        f"Object center transformation failed. Got {O_obj_center}, expected [0, 0, 0, 1]."

# %% [markdown]
# ### BBox Helpers

# %%
def get_bbox_dim_from_object(O_obj_corners: NDArray) -> NDArray:
    """
    Get the dimensions of the object's bounding box in the object's local coordinate frame.

    Computes the dimensions through the median of the object's corner vertices
    in the local coordinate frame.

    Args:
    -----
    O_obj_corners: NDArray (8, 3)
        Object's corner vertices
    
    Returns:
    --------
    box_dim: NDArray (3,)
        Dimensions of the object's bounding box in the local coordinate frame.
    """
    assert O_obj_corners.shape == (8, 3), f"O_obj_corners should be of shape (8, 3) but got {O_obj_corners.shape}"

    O_obj_corners = np.abs(O_obj_corners) # ignore direction: take the absolute value of all elements
    box_dim = np.median(O_obj_corners, axis=0) # take the median along all axes
    return 2*box_dim

# %%
def get_bbox_dim_from_camera(T_OC: NDArray, C_obj_corners):
    """
    Compute the bounding box dimensions of the object in the camera coordinate frame.

    Args:
    -----
    T_OC: NDArray (4, 4)
        Transformation matrix from camera to object coordinate frame
    C_obj_corners: NDArray (8, 3)
        Object's corner vertices in the camera coordinate frame
    
    Returns:
    --------
    box_dim: NDArray (3,)
        Dimensions of the object's bounding box in the camera coordinate frame.
    """
    assert T_OC.shape == (4, 4), f"T_OC should be of shape (4, 4) but got {T_OC.shape}"
    assert C_obj_corners.shape == (8, 3), f"C_obj_corners should be of shape (8, 3) but got {C_obj_corners.shape}"

    # transform object corners to object coordinate frame
    O_obj_corners = transfrom_pts(to_hom_3D(C_obj_corners), T_OC)
    O_obj_corners = to_cart_3D(O_obj_corners)
    # get object dimensions
    return get_bbox_dim_from_object(O_obj_corners)

# %% [markdown]
# ### Geometry Helpers

# %%
def line_plane_intersection(line_pt: NDArray, line_dir: NDArray, plane_vertices: NDArray):
    """
    Find the intersection, if any, of a line and a plane defined by 4 vertices.

    Parameters
    ----------
    line_pt : NDArray (3,)
        A point on the line.
    line_dir : NDArray (3,)
        The direction of the line.
    plane_vertices : NDArray (4,3)
        4 vertices defining the plane.
    
    Returns
    -------
    NDArray (3,) or None
        The intersection point or None if the line is parallel to the plane.
    """
    assert line_pt.shape == (3,)
    assert line_dir.shape == (3,)
    assert plane_vertices.shape == (4,3)

    plane_normal = np.cross(plane_vertices[1] - plane_vertices[0], plane_vertices[3] - plane_vertices[0])
    plane_norm = np.linalg.norm(plane_normal)
    assert plane_norm > 1e-6
    plane_normal /= plane_norm
    
    denom = np.dot(line_dir, plane_normal)
    if denom < 1e-15:
        # debug print TODO
        # print("| No I |", end="")
        return None # line is parallel to plane
    
    t = np.dot(plane_vertices[0] - line_pt, plane_normal) / denom
    intersection = line_pt + t * line_dir
    assert intersection.shape == (3,)
    return intersection

# %%
def is_in_face_object(bbox_dim: NDArray, O_pt: NDArray) -> bool:
    assert bbox_dim.shape == (3,), f"bbox_dim should be of shape (3,) but got {bbox_dim.shape}"
    assert O_pt.shape == (3,), f"O_pt should be of shape (3,) but got {O_pt.shape}"
    
    tol = np.double(0.1)
    bbox_r = bbox_dim/2

    # get absolute values
    O_pt = np.abs(O_pt)
    # check that each coordinate is within the box radii
    return np.all(O_pt <= bbox_r + tol)

# %% [markdown]
# ## New Implementation

# %% [markdown]
# Preparations

# %%
# Load number of sequences for selected mode
sample_ids = np.load(sample_root + 'sample_ids.npy')
n_sequences = sample_ids.shape[0]
print(f"Loaded {n_sequences} action sequences for {mode}.")

# path handling
hand_dir = sample_root + f'poses_hand_{mode}/'
obj_poses_dir = sample_root + f'poses_obj_{mode}/'
obj_rt_dir = sample_root + f'obj_rt_{mode}/'
dist_dir = sample_root + f'distances_{mode}/'
os.makedirs(dist_dir, exist_ok=True) # create the destination directory

# face indices according to h2o convention, but 0-indexed
faces_indices = [
        [0, 1, 2, 3], [4, 5, 6, 7], [0, 1, 5, 4], 
        [2, 3, 7, 6], [0, 3, 7, 4], [1, 2, 6, 5]
    ]
# Out:
# Loaded 569 action sequences for train.

# %%
def get_faces(obj_corners: NDArray) -> List[NDArray]:
    faces = []
    for face_indices in faces_indices:
        face = obj_corners[face_indices]
        faces.append(face)
    return faces

# %%
# for seq_id in range(1, n_sequences+1):
for seq_id in range(1, 14): # TODO
    print("\n\nSequence:", seq_id, '\n') # TODO
    n_dist_not_found = 0 # TODO

    # get poses of current sequence
    hand_poses = np.load(hand_dir + f'{seq_id:03d}.npy')
    obj_poses = np.load(obj_poses_dir + f'{seq_id:03d}.npy')
    obj_rts = np.load(obj_rt_dir + f'{seq_id:03d}.npy')
    assert hand_poses.shape == (n_frames_per_seq, 128)
    assert obj_poses.shape == (n_frames_per_seq, 64)
    assert obj_rts.shape == (n_frames_per_seq, 4, 4)

    for frame_id in range(n_frames_per_seq):
        hand_poses_left, hand_poses_right = format_hand_poses(hand_poses[frame_id])
        obj_center, obj_corners, obj_mid_edge = format_object_poses(obj_poses[frame_id])
        T_CO = obj_rts[frame_id]
        T_OC = invert_transformation_matrix(T_CO)

        assert_box_transform(T_OC, obj_center)

        # get object dimensions
        box_dim = (get_bbox_dim_from_camera(T_OC, obj_corners))
        # print("Object dimensions:", box_dim)

        # get faces
        faces = get_faces(obj_corners)
        # transfrom faces to object frame
        for face in faces:
            face = transfrom_pts(to_hom_3D(face), T_OC)
            face = to_cart_3D(face)

        # compute intersections
        for j in range(21):
            # TODO
            inters = []


            min_dist = 10.0
            found_dist = False

            joint = hand_poses_left[j]

            # transform joint to object frame
            joint = transfrom_pts(to_hom_3D(joint[np.newaxis, :]), T_OC)
            joint = to_cart_3D(joint)[0]

            # compute the line to the object's center
            center_vec = joint
            center_vec_norm = np.linalg.norm(center_vec)
            assert center_vec_norm > 1e-6
            center_vec /= center_vec_norm

            # debug print TODO
            # print("Computing distance for a joint...")
            # in_square_count = 0

            for face in faces:
                # compute the intersection point
                inter = line_plane_intersection(np.array([0.0, 0.0, 0.0], dtype=np.float64), center_vec, face)
                inters.append(inter)

                if inter is None:
                    continue

                # transform intersection point to object frame
                # inter = transfrom_pts(to_hom_3D(inter[np.newaxis, :]), T_OC)
                # inter = to_cart_3D(inter)[0]
                # print("Inter:", inter)

                # check if the intersection point is within the face
                if is_in_face_object(box_dim, inter):
                    # debug counter TODO
                    # in_square_count += 1

                    # compute the distance
                    dist = np.linalg.norm(inter - joint)
                    if dist < min_dist:
                        min_dist = dist
                    found_dist = True

            if not found_dist:
                print("No distance found:")
                print("Distance to center:", center_vec_norm)
                # print(inters)
                # print("Object center:", obj_center)
                # print("Joint:", joint)
                n_dist_not_found += 1
                # TODO
                # print("\n")
            
            
            # debug print TODO
            # print(f"Found {in_square_count} intersections in square.")
            
            # assert found_dist, "No distance found."
            # if found_dist: 
            #     return min_dist
            # else:
            #     return None

    print("Number of distances not found:", n_dist_not_found) # TODO
# Out:
# Sequence: 1
#
# No distance found:
# Distance to center: 0.2962043492977741
# No distance found:
# Distance to center: 0.2605344505317075
# No distance found:
# Distance to center: 0.23022317987624755
# No distance found:
# Distance to center: 0.20499729976837214
# No distance found:
# Distance to center: 0.18239906002769662
# No distance found:
# Distance to center: 0.21274075133876746
# No distance found:
# Distance to center: 0.1855195039892929
# No distance found:
# Distance to center: 0.1794090081368972
# No distance found:
# Distance to center: 0.1747185542650982
# No distance found:
# Distance to center: 0.22102921631727165
# No distance found:
# Distance to center: 0.19702300862710057
# No distance found:
# Distance to center: 0.18712956843997408
# No distance found:
# Distance to center: 0.18106206022572877
# No distance found:
# Distance to center: 0.2439884581028264
# No distance found:
# Distance to center: 0.2196249840819052
# No distance found:
# Distance to center: 0.20526947625754347
# No distance found:
# Distance to center: 0.1951289867452017
# No distance found:
# Distance to center: 0.26227632476206664
# No distance found:
# Distance to center: 0.24720931710799116
# No distance found:
# Distance to center: 0.23417914349678515
# No distance found:
# Distance to center: 0.22239204262282944
# No distance found:
# Distance to center: 0.280195588942008
# No distance found:
# Distance to center: 0.2481086552247163
# No distance found:
# Distance to center: 0.2185518940659343
# No distance found:
# Distance to center: 0.1921239758134446
# No distance found:
# Distance to center: 0.16241477213703176
# No distance found:
# Distance to center: 0.20152875329319017
# No distance found:
# Distance to center: 0.16916626542380955
# No distance found:
# Distance to center: 0.15552741718177784
# No distance found:
# Distance to center: 0.14468705678130614
# No distance found:
# Distance to center: 0.20421077795098266
# No distance found:
# Distance to center: 0.17518895085228486
# No distance found:
# Distance to center: 0.1596074666311989
# No distance found:
# Distance to center: 0.14977115711984865
# No distance found:
# Distance to center: 0.2209147498193014
# No distance found:
# Distance to center: 0.19424358016822602
# No distance found:
# Distance to center: 0.17435157651253125
# No distance found:
# Distance to center: 0.1596646412931092
# No distance found:
# Distance to center: 0.23469242837105775
# No distance found:
# Distance to center: 0.21785165283607774
# No distance found:
# Distance to center: 0.20218350156222883
# No distance found:
# Distance to center: 0.18914063825330496
# No distance found:
# Distance to center: 0.27885719713417123
# No distance found:
# Distance to center: 0.2472967503432876
# No distance found:
# Distance to center: 0.21808919871449098
# No distance found:
# Distance to center: 0.19201732345307515
# No distance found:
# Distance to center: 0.16190421676829253
# No distance found:
# Distance to center: 0.20244484594881648
# No distance found:
# Distance to center: 0.1699009886424124
# No distance found:
# Distance to center: 0.15505530513133187
# No distance found:
# Distance to center: 0.14223467212110844
# No distance found:
# Distance to center: 0.20464270208063826
# No distance found:
# Distance to center: 0.17505710455309922
# No distance found:
# Distance to center: 0.15797509225844014
# No distance found:
# Distance to center: 0.14571629300751382
# No distance found:
# Distance to center: 0.22014253167323677
# No distance found:
# Distance to center: 0.19333974721653052
# No distance found:
# Distance to center: 0.17249429524473697
# No distance found:
# Distance to center: 0.15679865338089075
# No distance found:
# Distance to center: 0.2329372650581268
# No distance found:
# Distance to center: 0.2155636125410912
# No distance found:
# Distance to center: 0.19946071647876734
# No distance found:
# Distance to center: 0.18525390233716707
# No distance found:
# Distance to center: 0.2811242571310301
# No distance found:
# Distance to center: 0.24950521947959375
# No distance found:
# Distance to center: 0.2203087771036468
# No distance found:
# Distance to center: 0.19441327828934776
# No distance found:
# Distance to center: 0.1642279685268227
# No distance found:
# Distance to center: 0.20402716626791373
# No distance found:
# Distance to center: 0.17181541341862966
# No distance found:
# Distance to center: 0.15676862120408552
# No distance found:
# Distance to center: 0.14470070886923997
# No distance found:
# Distance to center: 0.2062027314834084
# No distance found:
# Distance to center: 0.1764076302009699
# No distance found:
# Distance to center: 0.15892096198456818
# No distance found:
# Distance to center: 0.146393625510754
# No distance found:
# Distance to center: 0.22194512906302877
# No distance found:
# Distance to center: 0.19490774607642963
# No distance found:
# Distance to center: 0.17375650885605545
# No distance found:
# Distance to center: 0.1574762227474543
# No distance found:
# Distance to center: 0.2349581431574938
# No distance found:
# Distance to center: 0.21750082701140475
# No distance found:
# Distance to center: 0.20129033209614544
# No distance found:
# Distance to center: 0.1869500377000783
# No distance found:
# Distance to center: 0.2801547781957973
# No distance found:
# Distance to center: 0.24932929273651336
# No distance found:
# Distance to center: 0.22006823817725055
# No distance found:
# Distance to center: 0.1942504853472472
# No distance found:
# Distance to center: 0.16293376461568077
# No distance found:
# Distance to center: 0.20522950190791395
# No distance found:
# Distance to center: 0.17249857827624615
# No distance found:
# Distance to center: 0.15714537725896713
# No distance found:
# Distance to center: 0.14413858118975398
# No distance found:
# Distance to center: 0.20662665483902917
# No distance found:
# Distance to center: 0.17656662495419387
# No distance found:
# Distance to center: 0.15949274036873443
# No distance found:
# Distance to center: 0.14757063913025015
# No distance found:
# Distance to center: 0.2210135572665362
# No distance found:
# Distance to center: 0.19390937622803484
# No distance found:
# Distance to center: 0.17301647234288034
# No distance found:
# Distance to center: 0.15754376910188833
# No distance found:
# Distance to center: 0.23297664320407824
# No distance found:
# Distance to center: 0.2148015185698901
# No distance found:
# Distance to center: 0.1988370143417081
# No distance found:
# Distance to center: 0.18544821880520218
# No distance found:
# Distance to center: 0.280160126992892
# No distance found:
# Distance to center: 0.2501309254375435
# No distance found:
# Distance to center: 0.22077933859087243
# No distance found:
# Distance to center: 0.19456170154421873
# No distance found:
# Distance to center: 0.16320296786196328
# No distance found:
# Distance to center: 0.20390194815218798
# No distance found:
# Distance to center: 0.1708342973273888
# No distance found:
# Distance to center: 0.15722673015234204
# No distance found:
# Distance to center: 0.14558789622505855
# No distance found:
# Distance to center: 0.20414225484723686
# No distance found:
# Distance to center: 0.1738619777134664
# No distance found:
# Distance to center: 0.15908138211374023
# No distance found:
# Distance to center: 0.14983076838952994
# No distance found:
# Distance to center: 0.21824416625245002
# No distance found:
# Distance to center: 0.1898572275204685
# No distance found:
# Distance to center: 0.17287753299285466
# No distance found:
# Distance to center: 0.16305616394906686
# No distance found:
# Distance to center: 0.23023721905576292
# No distance found:
# Distance to center: 0.21036563188602392
# No distance found:
# Distance to center: 0.19729412914001865
# No distance found:
# Distance to center: 0.1879035893333084
# No distance found:
# Distance to center: 0.2807489457409493
# No distance found:
# Distance to center: 0.2503522049558061
# No distance found:
# Distance to center: 0.22080323509252725
# No distance found:
# Distance to center: 0.1948016424709085
# No distance found:
# Distance to center: 0.16300234336614375
# No distance found:
# Distance to center: 0.20486965658662148
# No distance found:
# Distance to center: 0.17223873765571607
# No distance found:
# Distance to center: 0.15685141061357138
# No distance found:
# Distance to center: 0.14268682929037316
# No distance found:
# Distance to center: 0.2056060860677759
# No distance found:
# Distance to center: 0.17660326038310703
# No distance found:
# Distance to center: 0.16213354872188573
# No distance found:
# Distance to center: 0.15059700881174562
# No distance found:
# Distance to center: 0.2198980573243905
# No distance found:
# Distance to center: 0.19174410253990298
# No distance found:
# Distance to center: 0.17664418881248464
# No distance found:
# Distance to center: 0.165272088825314
# No distance found:
# Distance to center: 0.23193666456980536
# No distance found:
# Distance to center: 0.2119405772971623
# No distance found:
# Distance to center: 0.19988233821752957
# No distance found:
# Distance to center: 0.19022704341175678
# Number of distances not found: 147
#
#
# Sequence: 2
#
# No distance found:
# Distance to center: 0.28179921425421167
# No distance found:
# Distance to center: 0.25150548074094203
# No distance found:
# Distance to center: 0.22198049214964877
# No distance found:
# Distance to center: 0.19607613459945158
# No distance found:
# Distance to center: 0.16414563697587486
# No distance found:
# Distance to center: 0.2058660082861704
# No distance found:
# Distance to center: 0.17345438504154603
# No distance found:
# Distance to center: 0.1575888100962146
# No distance found:
# Distance to center: 0.14263658509659527
# No distance found:
# Distance to center: 0.20645383121538563
# No distance found:
# Distance to center: 0.17775741638096418
# No distance found:
# Distance to center: 0.16398953678633102
# No distance found:
# Distance to center: 0.15374092399178627
# No distance found:
# Distance to center: 0.22066305026620453
# No distance found:
# Distance to center: 0.19248686282354602
# No distance found:
# Distance to center: 0.17739295531859628
# No distance found:
# Distance to center: 0.16614467580484946
# No distance found:
# Distance to center: 0.23265794668056844
# No distance found:
# Distance to center: 0.2125322330371618
# No distance found:
# Distance to center: 0.20018947355156758
# No distance found:
# Distance to center: 0.1903305696421224
# No distance found:
# Distance to center: 0.2825459200692138
# No distance found:
# Distance to center: 0.25263334434144763
# No distance found:
# Distance to center: 0.22295316981106067
# No distance found:
# Distance to center: 0.19689979695721285
# No distance found:
# Distance to center: 0.16517618113308166
# No distance found:
# Distance to center: 0.2071159041143351
# No distance found:
# Distance to center: 0.17442724286357114
# No distance found:
# Distance to center: 0.1585932584516898
# No distance found:
# Distance to center: 0.14341998623453625
# No distance found:
# Distance to center: 0.20727769322591216
# No distance found:
# Distance to center: 0.17862669605775994
# No distance found:
# Distance to center: 0.1641240687708111
# No distance found:
# Distance to center: 0.1527286731676317
# No distance found:
# Distance to center: 0.2210055415566524
# No distance found:
# Distance to center: 0.19274310885733056
# No distance found:
# Distance to center: 0.17641857650871304
# No distance found:
# Distance to center: 0.16490436620120041
# No distance found:
# Distance to center: 0.2326616755666417
# No distance found:
# Distance to center: 0.21247248777845879
# No distance found:
# Distance to center: 0.1995767045866407
# No distance found:
# Distance to center: 0.18955882615197553
# No distance found:
# Distance to center: 0.2825869044439745
# No distance found:
# Distance to center: 0.25253616219798136
# No distance found:
# Distance to center: 0.22306056314553582
# No distance found:
# Distance to center: 0.19703555457444172
# No distance found:
# Distance to center: 0.16547598136996422
# No distance found:
# Distance to center: 0.20788155179615464
# No distance found:
# Distance to center: 0.1751668113031685
# No distance found:
# Distance to center: 0.15951536123784615
# No distance found:
# Distance to center: 0.14366503443103143
# No distance found:
# Distance to center: 0.2083027676504921
# No distance found:
# Distance to center: 0.17975900893002425
# No distance found:
# Distance to center: 0.16536227374452192
# No distance found:
# Distance to center: 0.15290298957490714
# No distance found:
# Distance to center: 0.22193485320746859
# No distance found:
# Distance to center: 0.19374914429167533
# No distance found:
# Distance to center: 0.17839518722265954
# No distance found:
# Distance to center: 0.16720060415589538
# No distance found:
# Distance to center: 0.233435871948143
# No distance found:
# Distance to center: 0.21320796721370505
# No distance found:
# Distance to center: 0.20068901193148025
# No distance found:
# Distance to center: 0.19131260255724705
# No distance found:
# Distance to center: 0.2820539118318164
# No distance found:
# Distance to center: 0.2521137187977186
# No distance found:
# Distance to center: 0.2226796640638789
# No distance found:
# Distance to center: 0.19637766396100212
# No distance found:
# Distance to center: 0.1644598842616654
# No distance found:
# Distance to center: 0.20641495665989762
# No distance found:
# Distance to center: 0.17346708278057754
# No distance found:
# Distance to center: 0.1575206519623649
# No distance found:
# Distance to center: 0.1419036485427315
# No distance found:
# Distance to center: 0.2065921318551905
# No distance found:
# Distance to center: 0.177925898438175
# No distance found:
# Distance to center: 0.16367529206854695
# No distance found:
# Distance to center: 0.1525895238592628
# No distance found:
# Distance to center: 0.22041064170697006
# No distance found:
# Distance to center: 0.19215165083735236
# No distance found:
# Distance to center: 0.1760411748178931
# No distance found:
# Distance to center: 0.16480023580297906
# No distance found:
# Distance to center: 0.23214897105144727
# No distance found:
# Distance to center: 0.21189904074924956
# No distance found:
# Distance to center: 0.1984444676134888
# No distance found:
# Distance to center: 0.18753762624116277
# No distance found:
# Distance to center: 0.2773252242335649
# No distance found:
# Distance to center: 0.24700325975156012
# No distance found:
# Distance to center: 0.21764341023187564
# No distance found:
# Distance to center: 0.19101394879860153
# No distance found:
# Distance to center: 0.15941067238856185
# No distance found:
# Distance to center: 0.2000167168029902
# No distance found:
# Distance to center: 0.1669914591898515
# No distance found:
# Distance to center: 0.15305456172567541
# No distance found:
# Distance to center: 0.1392904675018935
# No distance found:
# Distance to center: 0.20055232255073252
# No distance found:
# Distance to center: 0.17231193512111123
# No distance found:
# Distance to center: 0.15948803750513607
# No distance found:
# Distance to center: 0.14985662869971442
# No distance found:
# Distance to center: 0.21526654998926928
# No distance found:
# Distance to center: 0.18735499899905622
# No distance found:
# Distance to center: 0.1728546369944686
# No distance found:
# Distance to center: 0.16221165106255775
# No distance found:
# Distance to center: 0.22776197491763447
# No distance found:
# Distance to center: 0.207987335645794
# No distance found:
# Distance to center: 0.195597385545482
# No distance found:
# Distance to center: 0.18597399524282748
# No distance found:
# Distance to center: 0.22913025102966106
# No distance found:
# Distance to center: 0.19963883421875975
# No distance found:
# Distance to center: 0.172977509069536
# No distance found:
# Distance to center: 0.14729571314146497
# No distance found:
# Distance to center: 0.1430789625713681
# No distance found:
# Distance to center: 0.14067835965289419
# No distance found:
# Distance to center: 0.16140500094319968
# No distance found:
# Distance to center: 0.15696043991250527
# No distance found:
# Distance to center: 0.1580720356386109
# No distance found:
# Distance to center: 0.18095177076065339
# No distance found:
# Distance to center: 0.17416625420988108
# No distance found:
# Distance to center: 0.17287006645419578
# No distance found:
# Distance to center: 0.22136907138425213
# No distance found:
# Distance to center: 0.20536615461658822
# No distance found:
# Distance to center: 0.19708973837099097
# No distance found:
# Distance to center: 0.1922419078327375
# No distance found:
# Distance to center: 0.25536825042167394
# No distance found:
# Distance to center: 0.2188422513316352
# No distance found:
# Distance to center: 0.18921215321972285
# No distance found:
# Distance to center: 0.16576205900328886
# No distance found:
# Distance to center: 0.14835864338638946
# No distance found:
# Distance to center: 0.15192859657138763
# No distance found:
# Distance to center: 0.1492387826677352
# No distance found:
# Distance to center: 0.14769229408211518
# No distance found:
# Distance to center: 0.17002090935597508
# No distance found:
# Distance to center: 0.16754599942774287
# No distance found:
# Distance to center: 0.16902001625262456
# No distance found:
# Distance to center: 0.2102959482446824
# No distance found:
# Distance to center: 0.19086785514155968
# No distance found:
# Distance to center: 0.18580067603740585
# No distance found:
# Distance to center: 0.18517542951328692
# No distance found:
# Distance to center: 0.2296963997792338
# No distance found:
# Distance to center: 0.2163055312677748
# No distance found:
# Distance to center: 0.2074327431879181
# No distance found:
# Distance to center: 0.2008055693544138
# No distance found:
# Distance to center: 0.2383780659999719
# No distance found:
# Distance to center: 0.20146038388289955
# No distance found:
# Distance to center: 0.17070201391137732
# No distance found:
# Distance to center: 0.14747649224081066
# No distance found:
# Distance to center: 0.1300873028056706
# No distance found:
# Distance to center: 0.13999498155428655
# No distance found:
# Distance to center: 0.1310575114103225
# No distance found:
# Distance to center: 0.12253602617303455
# No distance found:
# Distance to center: 0.17692492312095778
# No distance found:
# Distance to center: 0.15555306817494985
# No distance found:
# Distance to center: 0.14782857680900133
# No distance found:
# Distance to center: 0.14351708847549025
# No distance found:
# Distance to center: 0.19765009345696283
# No distance found:
# Distance to center: 0.17488457672486557
# No distance found:
# Distance to center: 0.16514379684788966
# No distance found:
# Distance to center: 0.16097682126893656
# No distance found:
# Distance to center: 0.21342176122439818
# No distance found:
# Distance to center: 0.19813747961913938
# No distance found:
# Distance to center: 0.1877313979333841
# No distance found:
# Distance to center: 0.1797792557946692
# Number of distances not found: 160
#
#
# Sequence: 3
#
# No distance found:
# Distance to center: 0.12574020198685365
# No distance found:
# Distance to center: 0.14330111388484812
# No distance found:
# Distance to center: 0.14109056346183244
# No distance found:
# Distance to center: 0.1951113225914763
# No distance found:
# Distance to center: 0.17575537829182428
# No distance found:
# Distance to center: 0.16300394697163456
# No distance found:
# Distance to center: 0.15786234446490235
# No distance found:
# Distance to center: 0.18642003021607062
# No distance found:
# Distance to center: 0.15197479733144267
# No distance found:
# Distance to center: 0.12054640964155645
# No distance found:
# Distance to center: 0.10473604785466793
# No distance found:
# Distance to center: 0.12025330269135799
# No distance found:
# Distance to center: 0.1301611042443597
# No distance found:
# Distance to center: 0.18143999519268952
# No distance found:
# Distance to center: 0.17737401110277495
# No distance found:
# Distance to center: 0.16470438975455845
# No distance found:
# Distance to center: 0.14069816001216132
# No distance found:
# Distance to center: 0.11491400720036549
# No distance found:
# Distance to center: 0.09775626699229537
# No distance found:
# Distance to center: 0.10799830611397199
# No distance found:
# Distance to center: 0.1539149152806624
# No distance found:
# Distance to center: 0.11892167613604548
# No distance found:
# Distance to center: 0.11083402703385928
# No distance found:
# Distance to center: 0.16095711822045888
# No distance found:
# Distance to center: 0.14005490051749483
# No distance found:
# Distance to center: 0.1178324308818443
# No distance found:
# Distance to center: 0.11139482163797497
# No distance found:
# Distance to center: 0.15494666806395743
# No distance found:
# Distance to center: 0.16151836189212093
# No distance found:
# Distance to center: 0.1353260152913833
# No distance found:
# Distance to center: 0.11462878756256462
# No distance found:
# Distance to center: 0.1077369019671978
# No distance found:
# Distance to center: 0.16049420055538421
# No distance found:
# Distance to center: 0.13612540483189195
# No distance found:
# Distance to center: 0.11618208645290096
# No distance found:
# Distance to center: 0.11343597620781014
# No distance found:
# Distance to center: 0.1584587104642327
# No distance found:
# Distance to center: 0.14093064332672678
# No distance found:
# Distance to center: 0.12383453926844827
# No distance found:
# Distance to center: 0.11288912319060977
# No distance found:
# Distance to center: 0.23616585878804752
# No distance found:
# Distance to center: 0.19507956787176584
# No distance found:
# Distance to center: 0.1943370977592734
# No distance found:
# Distance to center: 0.18911468203438841
# No distance found:
# Distance to center: 0.23977910710705228
# No distance found:
# Distance to center: 0.22738592048167433
# No distance found:
# Distance to center: 0.20942699291330977
# No distance found:
# Distance to center: 0.18915340138873302
# No distance found:
# Distance to center: 0.2542368541533837
# No distance found:
# Distance to center: 0.23646969650586244
# No distance found:
# Distance to center: 0.2167394207063593
# No distance found:
# Distance to center: 0.20254805875244877
# No distance found:
# Distance to center: 0.2587630913047143
# No distance found:
# Distance to center: 0.24173389521421984
# No distance found:
# Distance to center: 0.2221565797038362
# No distance found:
# Distance to center: 0.2122009900232633
# No distance found:
# Distance to center: 0.25965602951542227
# No distance found:
# Distance to center: 0.24219875256401507
# No distance found:
# Distance to center: 0.2250379750433731
# No distance found:
# Distance to center: 0.20985840768795852
# No distance found:
# Distance to center: 0.22979331117247737
# No distance found:
# Distance to center: 0.22782977195375947
# No distance found:
# Distance to center: 0.23910837801050697
# No distance found:
# Distance to center: 0.2491392070284136
# No distance found:
# Distance to center: 0.27951722277647356
# No distance found:
# Distance to center: 0.2815438723571534
# No distance found:
# Distance to center: 0.2682158342816182
# No distance found:
# Distance to center: 0.2519734692637175
# No distance found:
# Distance to center: 0.2962130967698417
# No distance found:
# Distance to center: 0.2834412857004962
# No distance found:
# Distance to center: 0.26238776362367794
# No distance found:
# Distance to center: 0.2435723608716787
# No distance found:
# Distance to center: 0.2979719543616377
# No distance found:
# Distance to center: 0.28346162445673373
# No distance found:
# Distance to center: 0.2621186412728884
# No distance found:
# Distance to center: 0.24117517452924833
# No distance found:
# Distance to center: 0.29635643036264564
# No distance found:
# Distance to center: 0.2852996174305251
# No distance found:
# Distance to center: 0.26817705699363564
# No distance found:
# Distance to center: 0.2529147655711745
# Number of distances not found: 80
#
#
# Sequence: 4
#
# No distance found:
# Distance to center: 0.2088622423772199
# No distance found:
# Distance to center: 0.20775163804365449
# No distance found:
# Distance to center: 0.22032970519943063
# No distance found:
# Distance to center: 0.23550980025946308
# No distance found:
# Distance to center: 0.25639929606541223
# No distance found:
# Distance to center: 0.2644168355926718
# No distance found:
# Distance to center: 0.25497477791802065
# No distance found:
# Distance to center: 0.24077658586618814
# No distance found:
# Distance to center: 0.27720598438193456
# No distance found:
# Distance to center: 0.27340615969899523
# No distance found:
# Distance to center: 0.2569584194917596
# No distance found:
# Distance to center: 0.23581365808611934
# No distance found:
# Distance to center: 0.2844231060892695
# No distance found:
# Distance to center: 0.27678590381446994
# No distance found:
# Distance to center: 0.25740227862277887
# No distance found:
# Distance to center: 0.23876731364778775
# No distance found:
# Distance to center: 0.2875509555148062
# No distance found:
# Distance to center: 0.2770132129966967
# No distance found:
# Distance to center: 0.2607888456521857
# No distance found:
# Distance to center: 0.24652902781353267
# No distance found:
# Distance to center: 0.21732110478723113
# No distance found:
# Distance to center: 0.21303116980613054
# No distance found:
# Distance to center: 0.22333750478475922
# No distance found:
# Distance to center: 0.2366052132145613
# No distance found:
# Distance to center: 0.2613774189529879
# No distance found:
# Distance to center: 0.26340704516833957
# No distance found:
# Distance to center: 0.2531159851333543
# No distance found:
# Distance to center: 0.23985724474546388
# No distance found:
# Distance to center: 0.2820832936572208
# No distance found:
# Distance to center: 0.2758852473146356
# No distance found:
# Distance to center: 0.2594425932188181
# No distance found:
# Distance to center: 0.23895870308255332
# No distance found:
# Distance to center: 0.2899227576672649
# No distance found:
# Distance to center: 0.28141723273150987
# No distance found:
# Distance to center: 0.2617536867724708
# No distance found:
# Distance to center: 0.24117714950019994
# No distance found:
# Distance to center: 0.2934187559706894
# No distance found:
# Distance to center: 0.28422530790915135
# No distance found:
# Distance to center: 0.268745229981417
# No distance found:
# Distance to center: 0.2535499988799409
# Number of distances not found: 40
#
#
# Sequence: 5
#
# No distance found:
# Distance to center: 0.23704847143154434
# No distance found:
# Distance to center: 0.20139897999745707
# No distance found:
# Distance to center: 0.17006423314693564
# No distance found:
# Distance to center: 0.14804916759887116
# No distance found:
# Distance to center: 0.17334850809317076
# No distance found:
# Distance to center: 0.21917135279393282
# No distance found:
# Distance to center: 0.1879836685091418
# No distance found:
# Distance to center: 0.15834089638344537
# No distance found:
# Distance to center: 0.13818346027314804
# No distance found:
# Distance to center: 0.1121462810515977
# No distance found:
# Distance to center: 0.16660331598764985
# No distance found:
# Distance to center: 0.1376950864163403
# No distance found:
# Distance to center: 0.12292068496217917
# No distance found:
# Distance to center: 0.1106719545415603
# No distance found:
# Distance to center: 0.1730352391308308
# No distance found:
# Distance to center: 0.1454073540990102
# No distance found:
# Distance to center: 0.13404702129330293
# No distance found:
# Distance to center: 0.12895406067869639
# No distance found:
# Distance to center: 0.18356032180868206
# No distance found:
# Distance to center: 0.15631571782947312
# No distance found:
# Distance to center: 0.14505699882922043
# No distance found:
# Distance to center: 0.14370855762671947
# No distance found:
# Distance to center: 0.19137716665500565
# No distance found:
# Distance to center: 0.1722806824927884
# No distance found:
# Distance to center: 0.16201149741378607
# No distance found:
# Distance to center: 0.1561246791220825
# No distance found:
# Distance to center: 0.22479168036354666
# No distance found:
# Distance to center: 0.19560846614949265
# No distance found:
# Distance to center: 0.16690866639823998
# No distance found:
# Distance to center: 0.14784219219994943
# No distance found:
# Distance to center: 0.12146095000726578
# No distance found:
# Distance to center: 0.1758922897938009
# No distance found:
# Distance to center: 0.14637696753526916
# No distance found:
# Distance to center: 0.13096692851507807
# No distance found:
# Distance to center: 0.11814287940217243
# No distance found:
# Distance to center: 0.1805929348433827
# No distance found:
# Distance to center: 0.15195016852879328
# No distance found:
# Distance to center: 0.13972953139811153
# No distance found:
# Distance to center: 0.13321682137440896
# No distance found:
# Distance to center: 0.18882152807211794
# No distance found:
# Distance to center: 0.16092816251188585
# No distance found:
# Distance to center: 0.1497938172283099
# No distance found:
# Distance to center: 0.14788172745118364
# No distance found:
# Distance to center: 0.19485801793724408
# No distance found:
# Distance to center: 0.17518049331880306
# No distance found:
# Distance to center: 0.16466298547532887
# No distance found:
# Distance to center: 0.15857243026734819
# No distance found:
# Distance to center: 0.23088506446849782
# No distance found:
# Distance to center: 0.20080735735109642
# No distance found:
# Distance to center: 0.17130915153631907
# No distance found:
# Distance to center: 0.15087104096551968
# No distance found:
# Distance to center: 0.12371963999342592
# No distance found:
# Distance to center: 0.1791048468918984
# No distance found:
# Distance to center: 0.1499723589921775
# No distance found:
# Distance to center: 0.13364695621398845
# No distance found:
# Distance to center: 0.11961203079561741
# No distance found:
# Distance to center: 0.1842071498585045
# No distance found:
# Distance to center: 0.1552266044595546
# No distance found:
# Distance to center: 0.1421154605620616
# No distance found:
# Distance to center: 0.13502193414169444
# No distance found:
# Distance to center: 0.19359578450577833
# No distance found:
# Distance to center: 0.16553629148300195
# No distance found:
# Distance to center: 0.15238721727017585
# No distance found:
# Distance to center: 0.14860186761936248
# No distance found:
# Distance to center: 0.20053587484666519
# No distance found:
# Distance to center: 0.18077493732119201
# No distance found:
# Distance to center: 0.1691013072114615
# No distance found:
# Distance to center: 0.1615697834445269
# No distance found:
# Distance to center: 0.23229483655825212
# No distance found:
# Distance to center: 0.20210927285225944
# No distance found:
# Distance to center: 0.172415624364917
# No distance found:
# Distance to center: 0.1522921154170093
# No distance found:
# Distance to center: 0.1256927628222861
# No distance found:
# Distance to center: 0.18005305018641335
# No distance found:
# Distance to center: 0.15164912988075058
# No distance found:
# Distance to center: 0.1347118076591104
# No distance found:
# Distance to center: 0.12055596165581611
# No distance found:
# Distance to center: 0.18517575506275036
# No distance found:
# Distance to center: 0.1562685333666363
# No distance found:
# Distance to center: 0.14294992495931153
# No distance found:
# Distance to center: 0.13539633952753502
# No distance found:
# Distance to center: 0.19472131681055813
# No distance found:
# Distance to center: 0.16669052133916976
# No distance found:
# Distance to center: 0.15316171218902294
# No distance found:
# Distance to center: 0.1490667921343557
# No distance found:
# Distance to center: 0.20178507686170036
# No distance found:
# Distance to center: 0.18203627890691157
# No distance found:
# Distance to center: 0.16997882068667494
# No distance found:
# Distance to center: 0.16231467777856798
# No distance found:
# Distance to center: 0.23272655634917327
# No distance found:
# Distance to center: 0.2028544899134013
# No distance found:
# Distance to center: 0.17351494442798976
# No distance found:
# Distance to center: 0.1541524491362496
# No distance found:
# Distance to center: 0.12815459060411125
# No distance found:
# Distance to center: 0.18243485241883495
# No distance found:
# Distance to center: 0.15315100551239624
# No distance found:
# Distance to center: 0.13733452140163746
# No distance found:
# Distance to center: 0.12424874767069567
# No distance found:
# Distance to center: 0.18758741866253797
# No distance found:
# Distance to center: 0.15857424418598404
# No distance found:
# Distance to center: 0.14555146395596905
# No distance found:
# Distance to center: 0.13858782514805884
# No distance found:
# Distance to center: 0.19659763692319618
# No distance found:
# Distance to center: 0.16842213057265598
# No distance found:
# Distance to center: 0.15537750477951728
# No distance found:
# Distance to center: 0.15202002142596208
# No distance found:
# Distance to center: 0.2031631976378729
# No distance found:
# Distance to center: 0.18327686894134051
# No distance found:
# Distance to center: 0.17169273787154954
# No distance found:
# Distance to center: 0.16455706258265307
# No distance found:
# Distance to center: 0.2344267635120514
# No distance found:
# Distance to center: 0.20498618692290427
# No distance found:
# Distance to center: 0.17606859261091054
# No distance found:
# Distance to center: 0.1578188352572515
# No distance found:
# Distance to center: 0.13262664874571914
# No distance found:
# Distance to center: 0.1850566435382272
# No distance found:
# Distance to center: 0.15422990053016197
# No distance found:
# Distance to center: 0.13856242001915206
# No distance found:
# Distance to center: 0.12493383322225346
# No distance found:
# Distance to center: 0.18987888827010344
# No distance found:
# Distance to center: 0.16057119074388945
# No distance found:
# Distance to center: 0.1467498354137725
# No distance found:
# Distance to center: 0.1400148747944798
# No distance found:
# Distance to center: 0.19838995600108789
# No distance found:
# Distance to center: 0.170155924187913
# No distance found:
# Distance to center: 0.15641640928805087
# No distance found:
# Distance to center: 0.1535275373757993
# No distance found:
# Distance to center: 0.2045534376408805
# No distance found:
# Distance to center: 0.18464344712638314
# No distance found:
# Distance to center: 0.17261771368275217
# No distance found:
# Distance to center: 0.16521378714664237
# Number of distances not found: 131
#
#
# Sequence: 6
#
# No distance found:
# Distance to center: 0.2349764386880455
# No distance found:
# Distance to center: 0.20553461250952815
# No distance found:
# Distance to center: 0.17662028611585726
# No distance found:
# Distance to center: 0.1584888728708411
# No distance found:
# Distance to center: 0.1329815393842109
# No distance found:
# Distance to center: 0.18352517818307984
# No distance found:
# Distance to center: 0.15191603430047976
# No distance found:
# Distance to center: 0.13674032641645587
# No distance found:
# Distance to center: 0.12483514947404303
# No distance found:
# Distance to center: 0.18789420173726698
# No distance found:
# Distance to center: 0.15857730194747394
# No distance found:
# Distance to center: 0.14527709260644278
# No distance found:
# Distance to center: 0.14123261588693678
# No distance found:
# Distance to center: 0.19666596999014918
# No distance found:
# Distance to center: 0.16852518819190826
# No distance found:
# Distance to center: 0.1560843301828333
# No distance found:
# Distance to center: 0.15576723424010777
# No distance found:
# Distance to center: 0.20316049813980577
# No distance found:
# Distance to center: 0.18344506111666756
# No distance found:
# Distance to center: 0.17190472156454562
# No distance found:
# Distance to center: 0.16543081709375476
# No distance found:
# Distance to center: 0.23393575928929394
# No distance found:
# Distance to center: 0.20460327927686356
# No distance found:
# Distance to center: 0.1757383336139967
# No distance found:
# Distance to center: 0.15705132786195908
# No distance found:
# Distance to center: 0.13104767522595936
# No distance found:
# Distance to center: 0.18340881182740737
# No distance found:
# Distance to center: 0.1514202252900684
# No distance found:
# Distance to center: 0.13685066268143345
# No distance found:
# Distance to center: 0.12492444414872547
# No distance found:
# Distance to center: 0.18785518492461367
# No distance found:
# Distance to center: 0.15857861827281775
# No distance found:
# Distance to center: 0.14509230864083192
# No distance found:
# Distance to center: 0.13983014319455303
# No distance found:
# Distance to center: 0.19641237763261438
# No distance found:
# Distance to center: 0.1682554503868666
# No distance found:
# Distance to center: 0.15512073575008753
# No distance found:
# Distance to center: 0.15363632604058283
# No distance found:
# Distance to center: 0.20270474032347677
# No distance found:
# Distance to center: 0.18298203040996755
# No distance found:
# Distance to center: 0.17104374966029903
# No distance found:
# Distance to center: 0.1635888931545642
# No distance found:
# Distance to center: 0.2328999949667687
# No distance found:
# Distance to center: 0.20418623019327853
# No distance found:
# Distance to center: 0.1756945276848405
# No distance found:
# Distance to center: 0.15797781652879572
# No distance found:
# Distance to center: 0.13240348166148722
# No distance found:
# Distance to center: 0.18537477966515373
# No distance found:
# Distance to center: 0.15320083854420488
# No distance found:
# Distance to center: 0.13837737871641853
# No distance found:
# Distance to center: 0.12568357786756237
# No distance found:
# Distance to center: 0.18975971605434333
# No distance found:
# Distance to center: 0.160545333396164
# No distance found:
# Distance to center: 0.14712849182633536
# No distance found:
# Distance to center: 0.14186582301896522
# No distance found:
# Distance to center: 0.19741407713962475
# No distance found:
# Distance to center: 0.169194391200897
# No distance found:
# Distance to center: 0.15580284182344661
# No distance found:
# Distance to center: 0.15393826169013552
# No distance found:
# Distance to center: 0.20290407210949288
# No distance found:
# Distance to center: 0.1830106033568759
# No distance found:
# Distance to center: 0.17067708178857366
# No distance found:
# Distance to center: 0.16251278692576007
# No distance found:
# Distance to center: 0.23058972121915752
# No distance found:
# Distance to center: 0.20166589914743274
# No distance found:
# Distance to center: 0.17296727543690998
# No distance found:
# Distance to center: 0.15535996449713305
# No distance found:
# Distance to center: 0.13038512650779838
# No distance found:
# Distance to center: 0.1825181388934454
# No distance found:
# Distance to center: 0.15077346783467793
# No distance found:
# Distance to center: 0.13611864617362546
# No distance found:
# Distance to center: 0.12515989015343942
# No distance found:
# Distance to center: 0.18704537496417867
# No distance found:
# Distance to center: 0.15791104240793108
# No distance found:
# Distance to center: 0.14427172254762954
# No distance found:
# Distance to center: 0.13823096914265812
# No distance found:
# Distance to center: 0.1949462239519039
# No distance found:
# Distance to center: 0.16676888535570358
# No distance found:
# Distance to center: 0.1536197902377957
# No distance found:
# Distance to center: 0.15222038092588988
# No distance found:
# Distance to center: 0.20065597879761707
# No distance found:
# Distance to center: 0.18076963052012848
# No distance found:
# Distance to center: 0.16886512713139287
# No distance found:
# Distance to center: 0.16196997873620306
# No distance found:
# Distance to center: 0.23042893247072951
# No distance found:
# Distance to center: 0.20051800723156935
# No distance found:
# Distance to center: 0.17158136487712178
# No distance found:
# Distance to center: 0.15366488335884762
# No distance found:
# Distance to center: 0.12930009387451183
# No distance found:
# Distance to center: 0.18107462696432033
# No distance found:
# Distance to center: 0.15027453087308681
# No distance found:
# Distance to center: 0.13552791468019743
# No distance found:
# Distance to center: 0.12381146431738559
# No distance found:
# Distance to center: 0.18649553094183952
# No distance found:
# Distance to center: 0.1576547148247285
# No distance found:
# Distance to center: 0.14525133180439434
# No distance found:
# Distance to center: 0.14020160128909598
# No distance found:
# Distance to center: 0.19542714355766555
# No distance found:
# Distance to center: 0.16747638387455857
# No distance found:
# Distance to center: 0.15493817119378234
# No distance found:
# Distance to center: 0.1532077097027578
# No distance found:
# Distance to center: 0.20188786644738102
# No distance found:
# Distance to center: 0.1821793193096971
# No distance found:
# Distance to center: 0.1708987777155386
# No distance found:
# Distance to center: 0.16445357932951182
# No distance found:
# Distance to center: 0.22814092033991476
# No distance found:
# Distance to center: 0.19382427115059872
# No distance found:
# Distance to center: 0.162924174161667
# No distance found:
# Distance to center: 0.1427311552227761
# No distance found:
# Distance to center: 0.12023520596911534
# No distance found:
# Distance to center: 0.16900746142582382
# No distance found:
# Distance to center: 0.1394898046708752
# No distance found:
# Distance to center: 0.13060485689201792
# No distance found:
# Distance to center: 0.12403726261398386
# No distance found:
# Distance to center: 0.17818183471819762
# No distance found:
# Distance to center: 0.1539042520033786
# No distance found:
# Distance to center: 0.1436350882229246
# No distance found:
# Distance to center: 0.1927398700449413
# No distance found:
# Distance to center: 0.16071915707616607
# Number of distances not found: 119
#
#
# Sequence: 7
#
# No distance found:
# Distance to center: 0.15665392185688035
# No distance found:
# Distance to center: 0.18189754350086876
# No distance found:
# Distance to center: 0.15496465029926104
# No distance found:
# Distance to center: 0.13420024668103664
# No distance found:
# Distance to center: 0.12560000043258535
# No distance found:
# Distance to center: 0.1123987142561255
# No distance found:
# Distance to center: 0.15997472033943122
# No distance found:
# Distance to center: 0.1511504222187841
# No distance found:
# Distance to center: 0.13255331253994637
# No distance found:
# Distance to center: 0.16862282992559624
# No distance found:
# Distance to center: 0.14759832026277306
# No distance found:
# Distance to center: 0.10559609036181422
# No distance found:
# Distance to center: 0.17280762910165998
# No distance found:
# Distance to center: 0.1522999979368012
# No distance found:
# Distance to center: 0.1107743978235246
# No distance found:
# Distance to center: 0.1749019097858481
# No distance found:
# Distance to center: 0.15794065315058056
# No distance found:
# Distance to center: 0.14052038481992649
# No distance found:
# Distance to center: 0.12494123905975886
# No distance found:
# Distance to center: 0.17130205796992226
# No distance found:
# Distance to center: 0.1487715857147605
# No distance found:
# Distance to center: 0.13330401199823264
# No distance found:
# Distance to center: 0.12848277054534818
# No distance found:
# Distance to center: 0.15595312630903763
# No distance found:
# Distance to center: 0.10221097941011696
# No distance found:
# Distance to center: 0.11585626667190839
# No distance found:
# Distance to center: 0.16116527474473233
# No distance found:
# Distance to center: 0.14291166948051323
# No distance found:
# Distance to center: 0.12693248092601406
# No distance found:
# Distance to center: 0.11987604153846176
# No distance found:
# Distance to center: 0.19253002218310533
# No distance found:
# Distance to center: 0.17206499523555388
# No distance found:
# Distance to center: 0.1456021190736213
# No distance found:
# Distance to center: 0.13081034563196053
# No distance found:
# Distance to center: 0.10760310463498517
# No distance found:
# Distance to center: 0.16644810175570576
# No distance found:
# Distance to center: 0.14905972263877415
# No distance found:
# Distance to center: 0.1288614391120449
# No distance found:
# Distance to center: 0.10952576761891829
# No distance found:
# Distance to center: 0.16726345095843653
# No distance found:
# Distance to center: 0.16625496140430623
# No distance found:
# Distance to center: 0.16499180407109756
# No distance found:
# Distance to center: 0.14801628483154136
# No distance found:
# Distance to center: 0.13099213048406258
# No distance found:
# Distance to center: 0.20027389651660935
# No distance found:
# Distance to center: 0.17297334981135082
# No distance found:
# Distance to center: 0.1426727476200801
# No distance found:
# Distance to center: 0.12752672947564073
# No distance found:
# Distance to center: 0.1100661633355573
# No distance found:
# Distance to center: 0.15494247822042062
# No distance found:
# Distance to center: 0.14718224036082952
# No distance found:
# Distance to center: 0.13708482081875742
# No distance found:
# Distance to center: 0.13269155317910555
# No distance found:
# Distance to center: 0.15844162399823203
# No distance found:
# Distance to center: 0.1463709064974763
# No distance found:
# Distance to center: 0.13368812261660093
# No distance found:
# Distance to center: 0.1646016050263737
# No distance found:
# Distance to center: 0.14781502107156833
# No distance found:
# Distance to center: 0.16933976489734012
# No distance found:
# Distance to center: 0.15255303670890238
# No distance found:
# Distance to center: 0.13508897046056775
# No distance found:
# Distance to center: 0.11743268152660574
# No distance found:
# Distance to center: 0.1995595380522752
# No distance found:
# Distance to center: 0.1766074624979788
# No distance found:
# Distance to center: 0.15066781978855676
# No distance found:
# Distance to center: 0.1337073178964483
# No distance found:
# Distance to center: 0.10990502184014936
# No distance found:
# Distance to center: 0.1707648348149099
# No distance found:
# Distance to center: 0.151385200877567
# No distance found:
# Distance to center: 0.13120726618522077
# No distance found:
# Distance to center: 0.11177913884108392
# No distance found:
# Distance to center: 0.17344463141231536
# No distance found:
# Distance to center: 0.15140365546220527
# No distance found:
# Distance to center: 0.1746309885376982
# No distance found:
# Distance to center: 0.17490831214397362
# No distance found:
# Distance to center: 0.15589207350640769
# No distance found:
# Distance to center: 0.13839340792774968
# No distance found:
# Distance to center: 0.12071184847425798
# No distance found:
# Distance to center: 0.20005458739048518
# No distance found:
# Distance to center: 0.17611411649112413
# No distance found:
# Distance to center: 0.1526979184284884
# No distance found:
# Distance to center: 0.14232960602414738
# No distance found:
# Distance to center: 0.12436081169137347
# No distance found:
# Distance to center: 0.1783989851380083
# No distance found:
# Distance to center: 0.1653134118361334
# No distance found:
# Distance to center: 0.1451574998126164
# No distance found:
# Distance to center: 0.12485038284523106
# No distance found:
# Distance to center: 0.18398701534822012
# No distance found:
# Distance to center: 0.16502573484599872
# No distance found:
# Distance to center: 0.18580835790465094
# No distance found:
# Distance to center: 0.18603421251825292
# No distance found:
# Distance to center: 0.19655207237703895
# No distance found:
# Distance to center: 0.17051506567236344
# No distance found:
# Distance to center: 0.14633358141684474
# No distance found:
# Distance to center: 0.1356951889230683
# No distance found:
# Distance to center: 0.12047923049146483
# No distance found:
# Distance to center: 0.18799926521669916
# No distance found:
# Distance to center: 0.1822694166028727
# No distance found:
# Distance to center: 0.16230448142620016
# No distance found:
# Distance to center: 0.14095944491430346
# No distance found:
# Distance to center: 0.19942681487718003
# No distance found:
# Distance to center: 0.18583410460550126
# No distance found:
# Distance to center: 0.16698437968779672
# No distance found:
# Distance to center: 0.1459034525446639
# No distance found:
# Distance to center: 0.20331794576737597
# No distance found:
# Distance to center: 0.1878843633385746
# No distance found:
# Distance to center: 0.1679237841493179
# No distance found:
# Distance to center: 0.14714368377608655
# No distance found:
# Distance to center: 0.20443270516864634
# No distance found:
# Distance to center: 0.18890449778034657
# No distance found:
# Distance to center: 0.1737564606918921
# No distance found:
# Distance to center: 0.15974758134958533
# Number of distances not found: 112
#
#
# Sequence: 8
#
# No distance found:
# Distance to center: 0.28165192546749374
# No distance found:
# Distance to center: 0.24405834292417428
# No distance found:
# Distance to center: 0.2134668330463561
# No distance found:
# Distance to center: 0.19135184553623
# No distance found:
# Distance to center: 0.1683311951342219
# No distance found:
# Distance to center: 0.21301316211822952
# No distance found:
# Distance to center: 0.18709295976485174
# No distance found:
# Distance to center: 0.18161106805423624
# No distance found:
# Distance to center: 0.1777647888128083
# No distance found:
# Distance to center: 0.2249168645348315
# No distance found:
# Distance to center: 0.20491124748512207
# No distance found:
# Distance to center: 0.19961457574955258
# No distance found:
# Distance to center: 0.20181641517249188
# No distance found:
# Distance to center: 0.2449986418450063
# No distance found:
# Distance to center: 0.2229194979545227
# No distance found:
# Distance to center: 0.21609565521210852
# No distance found:
# Distance to center: 0.21867739500652494
# No distance found:
# Distance to center: 0.2599175265543605
# No distance found:
# Distance to center: 0.24496731625504975
# No distance found:
# Distance to center: 0.23633390465827994
# No distance found:
# Distance to center: 0.23374305398029596
# No distance found:
# Distance to center: 0.2325932843296889
# No distance found:
# ...
# No distance found:
# Distance to center: 0.14425807977996963
# No distance found:
# Distance to center: 0.13161066505336033
# No distance found:
# Distance to center: 0.12043113505946555
# No distance found:
# Distance to center: 0.11204712091142234
# No distance found:
# Distance to center: 0.15598997876021894
# No distance found:
# Distance to center: 0.13842212717978
# No distance found:
# Distance to center: 0.12419578796360259
# No distance found:
# Distance to center: 0.1111810052193369
# No distance found:
# Distance to center: 0.16968972503709248
# No distance found:
# Distance to center: 0.1516621534877171
# No distance found:
# Distance to center: 0.13579872055852613
# No distance found:
# Distance to center: 0.12166203539839095
# No distance found:
# Distance to center: 0.17961772600789683
# No distance found:
# Distance to center: 0.1627523296724967
# No distance found:
# Distance to center: 0.14757974560437212
# No distance found:
# Distance to center: 0.13260838938466654
# No distance found:
# Distance to center: 0.17831708715838032
# No distance found:
# Distance to center: 0.14032991332556238
# No distance found:
# Distance to center: 0.11032156459750952
# No distance found:
# Distance to center: 0.09633119808339674
# No distance found:
# Distance to center: 0.08481047437467984
# No distance found:
# Distance to center: 0.12714835284606635
# No distance found:
# Distance to center: 0.12086055176678169
# No distance found:
# Distance to center: 0.11707226562972732
# No distance found:
# Distance to center: 0.11369819327546052
# No distance found:
# Distance to center: 0.14400091809443355
# No distance found:
# Distance to center: 0.13586887138986442
# No distance found:
# Distance to center: 0.1260599301233354
# No distance found:
# Distance to center: 0.1162251285035934
# No distance found:
# Distance to center: 0.16147365978135575
# No distance found:
# Distance to center: 0.1484239854092942
# No distance found:
# Distance to center: 0.1337191850783631
# No distance found:
# Distance to center: 0.12029320674848998
# No distance found:
# Distance to center: 0.17409961244710706
# No distance found:
# Distance to center: 0.1627769534715758
# No distance found:
# Distance to center: 0.14966610212246512
# No distance found:
# Distance to center: 0.1377988815138293
# No distance found:
# Distance to center: 0.17520872165001358
# No distance found:
# Distance to center: 0.1390603627485113
# No distance found:
# Distance to center: 0.11079287051006466
# No distance found:
# Distance to center: 0.09686291052122667
# No distance found:
# Distance to center: 0.08317233281028501
# No distance found:
# Distance to center: 0.12794312898021018
# No distance found:
# Distance to center: 0.12011042960415529
# No distance found:
# Distance to center: 0.1142359441003845
# No distance found:
# Distance to center: 0.10919564756089849
# No distance found:
# Distance to center: 0.14250959858854478
# No distance found:
# Distance to center: 0.13869001460478178
# No distance found:
# Distance to center: 0.1287113215098237
# No distance found:
# Distance to center: 0.11691103819686828
# No distance found:
# Distance to center: 0.1571472616960554
# No distance found:
# Distance to center: 0.1522773696042777
# No distance found:
# Distance to center: 0.13808754974431547
# No distance found:
# Distance to center: 0.12293263866189703
# No distance found:
# Distance to center: 0.16770930246380428
# No distance found:
# Distance to center: 0.16202874838542117
# No distance found:
# Distance to center: 0.15017793170901791
# No distance found:
# Distance to center: 0.13863355449999412
# No distance found:
# Distance to center: 0.17170503132091797
# No distance found:
# Distance to center: 0.1409371664075262
# No distance found:
# Distance to center: 0.11616339569829584
# No distance found:
# Distance to center: 0.10145048141375694
# No distance found:
# Distance to center: 0.08266665785030594
# No distance found:
# Distance to center: 0.12833494599769474
# No distance found:
# Distance to center: 0.11620305315029816
# No distance found:
# Distance to center: 0.10843118015340526
# No distance found:
# Distance to center: 0.1063147267208346
# No distance found:
# Distance to center: 0.13665233800048107
# No distance found:
# Distance to center: 0.13008441498852338
# No distance found:
# Distance to center: 0.12421675761079629
# No distance found:
# Distance to center: 0.12410218103080546
# No distance found:
# Distance to center: 0.14554652003683569
# No distance found:
# Distance to center: 0.13405239822872295
# No distance found:
# Distance to center: 0.12518426746381325
# No distance found:
# Distance to center: 0.12120141851172879
# No distance found:
# Distance to center: 0.15223634344553608
# No distance found:
# Distance to center: 0.14333115974583316
# No distance found:
# Distance to center: 0.13286664461697983
# No distance found:
# Distance to center: 0.12605487005581845
# No distance found:
# Distance to center: 0.18075096905635613
# No distance found:
# Distance to center: 0.15567154816261514
# No distance found:
# Distance to center: 0.13489306960052574
# No distance found:
# Distance to center: 0.12056611628380223
# No distance found:
# Distance to center: 0.10054162010278732
# No distance found:
# Distance to center: 0.13911416705067017
# No distance found:
# Distance to center: 0.12445316261469923
# No distance found:
# Distance to center: 0.11418856492447857
# No distance found:
# Distance to center: 0.1099314605443066
# No distance found:
# Distance to center: 0.14109065843695082
# No distance found:
# Distance to center: 0.1247335210152827
# No distance found:
# Distance to center: 0.1088677034137472
# No distance found:
# Distance to center: 0.09337756133728752
# No distance found:
# Distance to center: 0.14492571313253266
# No distance found:
# Distance to center: 0.12651880554685177
# No distance found:
# Distance to center: 0.10509957739574742
# No distance found:
# Distance to center: 0.0838659148258714
# No distance found:
# Distance to center: 0.14822448751535916
# No distance found:
# Distance to center: 0.13236864756122455
# No distance found:
# Distance to center: 0.11559509550843024
# No distance found:
# Distance to center: 0.09937486491942438
# No distance found:
# Distance to center: 0.05235928014510254
# No distance found:
# Distance to center: 0.06444214182157729
# Number of distances not found: 128
#
#
# Sequence: 12
#
# Number of distances not found: 0
#
#
# Sequence: 13
#
# No distance found:
# Distance to center: 0.25433401879312917
# No distance found:
# Distance to center: 0.22009509688896411
# No distance found:
# Distance to center: 0.18951806881684857
# No distance found:
# Distance to center: 0.16937628526237478
# No distance found:
# Distance to center: 0.14592596573793987
# No distance found:
# Distance to center: 0.19815204548831877
# No distance found:
# Distance to center: 0.16855955840108433
# No distance found:
# Distance to center: 0.15762852414792894
# No distance found:
# Distance to center: 0.14725105030285945
# No distance found:
# Distance to center: 0.20740405591244324
# No distance found:
# Distance to center: 0.18248999241510633
# No distance found:
# Distance to center: 0.17248809550232674
# No distance found:
# Distance to center: 0.1689566589780354
# No distance found:
# Distance to center: 0.2213504590654555
# No distance found:
# Distance to center: 0.19564934272317686
# No distance found:
# Distance to center: 0.1855186938708187
# No distance found:
# Distance to center: 0.1853558058286635
# No distance found:
# Distance to center: 0.23136823655302513
# No distance found:
# Distance to center: 0.213224379702158
# No distance found:
# Distance to center: 0.20401357957245633
# No distance found:
# Distance to center: 0.19948918744632768
# No distance found:
# Distance to center: 0.24357833564388714
# No distance found:
# Distance to center: 0.21398330436138746
# No distance found:
# Distance to center: 0.18434364273685191
# No distance found:
# Distance to center: 0.16367734094323688
# No distance found:
# Distance to center: 0.13626623548008396
# No distance found:
# Distance to center: 0.19154069871008617
# No distance found:
# Distance to center: 0.1589389003285007
# No distance found:
# Distance to center: 0.1443356249243248
# No distance found:
# Distance to center: 0.12989982685023013
# No distance found:
# Distance to center: 0.19589258339541865
# No distance found:
# Distance to center: 0.16761305116224198
# No distance found:
# Distance to center: 0.1557469998041528
# No distance found:
# Distance to center: 0.1516799832634435
# No distance found:
# Distance to center: 0.20486551885741786
# No distance found:
# Distance to center: 0.17718832210369476
# No distance found:
# Distance to center: 0.16590908108198435
# No distance found:
# Distance to center: 0.1660778101301005
# No distance found:
# Distance to center: 0.21146325320667944
# No distance found:
# Distance to center: 0.19195979894749587
# No distance found:
# Distance to center: 0.1824813341619367
# No distance found:
# Distance to center: 0.17926068876251322
# No distance found:
# Distance to center: 0.2542871622092778
# No distance found:
# Distance to center: 0.2259103234796283
# No distance found:
# Distance to center: 0.19683901597988873
# No distance found:
# Distance to center: 0.17637719841060642
# No distance found:
# Distance to center: 0.14824330994260268
# No distance found:
# Distance to center: 0.20213534514196269
# No distance found:
# Distance to center: 0.16937792097800408
# No distance found:
# Distance to center: 0.15435815555830468
# No distance found:
# Distance to center: 0.1406663981625061
# No distance found:
# Distance to center: 0.20494038933199923
# No distance found:
# Distance to center: 0.17566019208767664
# No distance found:
# Distance to center: 0.16360788591642528
# No distance found:
# Distance to center: 0.15903721545188637
# No distance found:
# Distance to center: 0.21284262554765515
# No distance found:
# Distance to center: 0.1845794602051187
# No distance found:
# Distance to center: 0.17329021263770247
# No distance found:
# Distance to center: 0.1739494032422955
# No distance found:
# Distance to center: 0.21870604589256573
# No distance found:
# Distance to center: 0.1986540175564765
# No distance found:
# Distance to center: 0.18912416887458341
# No distance found:
# Distance to center: 0.18595335469426033
# No distance found:
# Distance to center: 0.2510645605434772
# No distance found:
# Distance to center: 0.22335975120582413
# No distance found:
# Distance to center: 0.19452476463931384
# No distance found:
# Distance to center: 0.1744398583212643
# No distance found:
# Distance to center: 0.14658079849794553
# No distance found:
# Distance to center: 0.20159064670193896
# No distance found:
# Distance to center: 0.16902695858440364
# No distance found:
# Distance to center: 0.15337561101391572
# No distance found:
# Distance to center: 0.13879925670331708
# No distance found:
# Distance to center: 0.20423946690156963
# No distance found:
# Distance to center: 0.17477161199547653
# No distance found:
# Distance to center: 0.16227540247371278
# No distance found:
# Distance to center: 0.15713173505366637
# No distance found:
# Distance to center: 0.21123588538198826
# No distance found:
# Distance to center: 0.18281631109249
# No distance found:
# Distance to center: 0.17135669504471826
# No distance found:
# Distance to center: 0.17167028106309412
# No distance found:
# Distance to center: 0.21632855909399315
# No distance found:
# Distance to center: 0.19612138416757077
# No distance found:
# Distance to center: 0.18668961843494733
# No distance found:
# Distance to center: 0.18355989574344772
# No distance found:
# Distance to center: 0.25168942691836715
# No distance found:
# Distance to center: 0.2231449854414243
# No distance found:
# Distance to center: 0.19401154996274103
# No distance found:
# Distance to center: 0.17392144121953423
# No distance found:
# Distance to center: 0.14637006501687527
# No distance found:
# Distance to center: 0.2006152390709741
# No distance found:
# Distance to center: 0.16793560897297113
# No distance found:
# Distance to center: 0.15278945753763942
# No distance found:
# Distance to center: 0.1395154481491991
# No distance found:
# Distance to center: 0.2038738523134712
# No distance found:
# Distance to center: 0.17478440958865235
# No distance found:
# Distance to center: 0.16252706102613268
# No distance found:
# Distance to center: 0.15806588876830838
# No distance found:
# Distance to center: 0.211789291464142
# No distance found:
# Distance to center: 0.1836373752525448
# No distance found:
# Distance to center: 0.17224021658550198
# No distance found:
# Distance to center: 0.1738023752603691
# No distance found:
# Distance to center: 0.21758536570218373
# No distance found:
# Distance to center: 0.19754060786925284
# No distance found:
# Distance to center: 0.18797543459816482
# No distance found:
# Distance to center: 0.1857422271795172
# No distance found:
# Distance to center: 0.2482986693608386
# No distance found:
# Distance to center: 0.22105196259279347
# No distance found:
# Distance to center: 0.19266955000692232
# No distance found:
# Distance to center: 0.17370354650485803
# No distance found:
# Distance to center: 0.1463854077859984
# No distance found:
# Distance to center: 0.20157068671997078
# No distance found:
# Distance to center: 0.16844583717589293
# No distance found:
# Distance to center: 0.15285073580905134
# No distance found:
# Distance to center: 0.13830214751066
# No distance found:
# Distance to center: 0.20434596967280957
# No distance found:
# Distance to center: 0.17476326116993487
# No distance found:
# Distance to center: 0.16198468832656182
# No distance found:
# Distance to center: 0.15751345668310537
# No distance found:
# Distance to center: 0.21064540822413189
# No distance found:
# Distance to center: 0.18215889896722817
# No distance found:
# Distance to center: 0.17061792467736725
# No distance found:
# Distance to center: 0.17152980879692215
# No distance found:
# Distance to center: 0.215090872599603
# No distance found:
# Distance to center: 0.19494406619368324
# No distance found:
# Distance to center: 0.18624984902965305
# No distance found:
# Distance to center: 0.18324482031040132
# No distance found:
# Distance to center: 0.24970284261822578
# No distance found:
# Distance to center: 0.22573320353998438
# No distance found:
# Distance to center: 0.1990123943352306
# No distance found:
# Distance to center: 0.18043109830933046
# No distance found:
# Distance to center: 0.15192853113214508
# No distance found:
# Distance to center: 0.20601383949025737
# No distance found:
# Distance to center: 0.1729241052960911
# No distance found:
# Distance to center: 0.1565550768648587
# No distance found:
# Distance to center: 0.14157385278842236
# No distance found:
# Distance to center: 0.20586228593314027
# No distance found:
# Distance to center: 0.17520570823762627
# No distance found:
# Distance to center: 0.16085335484880048
# No distance found:
# Distance to center: 0.15374236648428927
# No distance found:
# Distance to center: 0.20911776556519598
# No distance found:
# Distance to center: 0.18021027445380375
# No distance found:
# Distance to center: 0.16648071929756267
# No distance found:
# Distance to center: 0.16447588232316385
# No distance found:
# Distance to center: 0.21140108091327772
# No distance found:
# Distance to center: 0.19055810975613224
# No distance found:
# Distance to center: 0.17984475899280666
# No distance found:
# Distance to center: 0.17523484554718022
# No distance found:
# Distance to center: 0.2741227945846015
# No distance found:
# Distance to center: 0.2555302901196112
# No distance found:
# Distance to center: 0.23219374109642174
# No distance found:
# Distance to center: 0.2154685997137452
# No distance found:
# Distance to center: 0.18740387331264488
# No distance found:
# Distance to center: 0.23288988291331156
# No distance found:
# Distance to center: 0.2013363661115264
# No distance found:
# Distance to center: 0.18466013008843676
# No distance found:
# Distance to center: 0.17110063737940834
# No distance found:
# Distance to center: 0.22764544584884203
# No distance found:
# Distance to center: 0.19679444925370568
# No distance found:
# Distance to center: 0.18283116492713739
# No distance found:
# Distance to center: 0.1764114445197556
# No distance found:
# Distance to center: 0.22651725130620354
# No distance found:
# Distance to center: 0.19847242701970802
# No distance found:
# Distance to center: 0.18544404769671471
# No distance found:
# Distance to center: 0.18305247192443708
# No distance found:
# Distance to center: 0.22573615600215974
# No distance found:
# Distance to center: 0.205329765965002
# No distance found:
# Distance to center: 0.1961061708486067
# No distance found:
# Distance to center: 0.19131594314268122
# Number of distances not found: 168

# %% [markdown]
# ## Old Implementation

# %% [markdown]
# Load Pose Sequences

# %%
action_labels = np.load(h2o_root + f'action_labels_{mode}.npy')
n_sequences = action_labels.shape[0]
print(f"Loaded {n_sequences} action sequences for {mode}.")
# Out:
# Loaded 569 action sequences for train.

# %%
def line_plane_intersection(line_pt: NDArray, line_dir: NDArray, plane_vertices: NDArray):
    """
    Find the intersection, if any, of a line and a plane defined by 4 vertices.

    Parameters
    ----------
    line_pt : NDArray (3,)
        A point on the line.
    line_dir : NDArray (3,)
        The direction of the line.
    plane_vertices : NDArray (4,3)
        4 vertices defining the plane.
    
    Returns
    -------
    NDArray (3,) or None
        The intersection point or None if the line is parallel to the plane.
    """
    assert line_pt.shape == (3,)
    assert line_dir.shape == (3,)
    assert plane_vertices.shape == (4,3)

    plane_normal = np.cross(plane_vertices[1] - plane_vertices[0], plane_vertices[3] - plane_vertices[0])
    plane_norm = np.linalg.norm(plane_normal)
    assert plane_norm > 1e-6
    plane_normal /= plane_norm
    
    denom = np.dot(line_dir, plane_normal)
    if denom < 1e-12:
        # debug print TODO
        # print("| No I |", end="")
        return None # line is parallel to plane
    
    t = np.dot(plane_vertices[0] - line_pt, plane_normal) / denom
    intersection = line_pt + t * line_dir
    assert intersection.shape == (3,)
    return intersection

# %%
def is_pt_in_rect(pt: NDArray, rect_vertices: NDArray) -> bool:
    """
    Check whether a point is within a rectangle defined by the 4 vertices.

    Parameters
    ----------
    pt : NDArray (3,)
        The point to check.
    rect_vertices : NDArray (4, 3)
        The vertices of the rectangle, such that succeeding vertices are connected.

    Returns
    -------
    bool
        Whether the point is within the rectangle.


    Algorithm:
    Take 3 consecutive vertices ABC of the rectangle and the sample point P.
    P is inside the rectangle, iff 
    0 <= dot(AB, AP) <= dot(AB, AB) and 
    0 <= dot(BC, BP) <= dot(BC, BC)
    """
    assert pt.shape == (3,)
    assert rect_vertices.shape == (4, 3)
    tol = np.double(1.0)

    # compute AB, BC
    edge1 = rect_vertices[1] - rect_vertices[0]
    edge2 = rect_vertices[2] - rect_vertices[1]
    # compute AP, BP
    vec1 = pt - rect_vertices[0]
    vec2 = pt - rect_vertices[1]

    return -tol <= np.dot(edge1, vec1) <= np.dot(edge1, edge1) + tol and -tol <= np.dot(edge2, vec2) <= np.dot(edge2, edge2) + tol


    # dennis
    # total_angle = 0
    # for i in range(rect_vertices.shape[0]):
    #     a, b = rect_vertices[i], rect_vertices[(i + 1) % len(rect_vertices)]
    #     da, db = a - pt, b - pt
    #     angle = np.arctan2(np.linalg.norm(np.cross(da, db)), np.dot(da, db))
    #     total_angle += angle
    # return np.isclose(total_angle, 2 * np.pi, atol=1e-5)

# %%
def dist_joint_bbox(joint: NDArray, center: NDArray, faces: NDArray):
    """
    Compute the distance from a joint to the bounding box of an object.

    Parameters
    ----------
    joint : NDArray (3,)
        The joint position.
    center : NDArray (3,)
        The object's center.
    faces : List[NDArray (4,3)]
        The faces of the object's bounding box.
    
    Returns
    -------
    float
        The minimum distance from the joint to the bounding box.

    Exceptions
    ----------
    AssertionError
        If no distance is found.
    """
    assert joint.shape == (3,)
    assert center.shape == (3,)
    assert faces[0].shape == (4, 3)
    
    min_dist = 10.0
    found_dist = False

    # compute the line to the object's center
    center_vec = center - joint
    center_vec_norm = np.linalg.norm(center_vec)
    assert center_vec_norm > 1e-6
    center_vec /= center_vec_norm

    # debug print TODO
    # print("Computing distance for a joint...")
    # in_square_count = 0

    for face in faces:
        # compute the intersection point
        inter = line_plane_intersection(joint, center_vec, face)

        # check if the intersection point is within the face
        if inter is not None and is_pt_in_rect(inter, face):
            # debug counter TODO
            # in_square_count += 1

            # compute the distance
            dist = np.linalg.norm(inter - joint)
            if dist < min_dist:
                min_dist = dist
            found_dist = True
    
    # debug print TODO
    # print(f"Found {in_square_count} intersections in square.")
    
    # assert found_dist, "No distance found."
    if found_dist: 
        return min_dist
    else:
        return None

    # return min_dist

# %%
# path handling
pose_root = h2o_root + f'seq_{n_frames_per_seq}_{mode}/'
hand_dir = pose_root + f'poses_hand_{mode}/'
obj_dir = pose_root + f'poses_obj_{mode}/'
dist_dir = pose_root + f'distances_{mode}/'
# os.makedirs(dist_dir, exist_ok=True) # create the destination directory

# face indices according to h2o convention, but 0-indexed
faces_indices = [
        [0, 1, 2, 3], [4, 5, 6, 7], [0, 1, 5, 4], 
        [2, 3, 7, 6], [0, 3, 7, 4], [1, 2, 6, 5]
    ]

# for each sequence TODO
for seq_id in range(1, n_sequences+1):
    print("\n\nSequence:", seq_id, '\n') # TODO
    no_dist = 0

    # get poses of current sequence
    hand_poses = np.load(hand_dir + f'{seq_id:03d}.npy')
    obj_poses = np.load(obj_dir + f'{seq_id:03d}.npy')
    assert hand_poses.shape[0] == n_frames_per_seq
    assert hand_poses.shape[1] == 128
    assert obj_poses.shape[0] == n_frames_per_seq
    assert obj_poses.shape[1] == 64

    # prepare distance array
    dist_array = np.zeros((n_frames_per_seq, 42))

    # for each frame TODO
    for frame_id in range(0, n_frames_per_seq):
        # print("\n\nFrame:", frame_id, '\n') # TODO
        
        # get and format hand poses of current frame
        hand_poses_left = hand_poses[frame_id, 1:64].reshape((21, 3))
        hand_poses_right = hand_poses[frame_id, 65:].reshape((21, 3))

        # extract object center point
        obj_center = obj_poses[frame_id, 1:4]
        # extract object corner vertices
        obj_corner_vert = obj_poses[frame_id, 4:]
        obj_corner_vert = obj_corner_vert[:8*3]
        obj_corner_vert = obj_corner_vert.reshape((8, 3))
        # extract faces as (4,3) arrays from the corner vertices according to the face indices
        faces = []
        for face_indices in faces_indices:
            face = obj_corner_vert[face_indices]
            faces.append(face)

        # for each joint
        for j in range(21):
            # print("\nJoint:", j) # TODO
            # compute the line to the object's center
            # print("\nLeft") # TODO
            distance_left = dist_joint_bbox(hand_poses_left[j], obj_center, faces)
            # print("\nRight") # TODO
            # print("Point:", hand_poses_right[j]) # TODO
            # print("BBox", faces) # TODO
            distance_right = dist_joint_bbox(hand_poses_right[j], obj_center, faces)
            # print("Distance:", distance_right) # TODO

            if distance_left is None:
                no_dist += 1
                print("No dist in frame", frame_id, "for left join", j)
            if distance_right is None:
                no_dist += 1
                print("No dist in frame", frame_id, "for right join", j)

            # write distance to array TODO
            # dist_array[frame_id, j] = distance_left
            # dist_array[frame_id, j+21] = distance_right

    # TODO 
    print("No distances found:", no_dist)
    # save the distance array

# output array
# for each sequence a file
# array (n_sequences, 42)
# Out:
# Sequence: 1
#
# No distances found: 0
#
#
# Sequence: 2
#
# No distances found: 0
#
#
# Sequence: 3
#
# No distances found: 0
#
#
# Sequence: 4
#
# No distances found: 0
#
#
# Sequence: 5
#
# No distances found: 0
#
#
# Sequence: 6
#
# No dist in frame 2 for right join 13
# No distances found: 1
#
#
# Sequence: 7
#
# No distances found: 0
#
#
# Sequence: 8
#
# No distances found: 0
#
#
# Sequence: 9
#
# No distances found: 0
#
#
# Sequence: 10
#
# No dist in frame 0 for left join 10
# No dist in frame 0 for left join 11
# No dist in frame 1 for left join 14
# No dist in frame 2 for left join 14
# No dist in frame 3 for left join 12
# No dist in frame 3 for left join 15
# No dist in frame 4 for left join 11
# No dist in frame 4 for left join 12
# No distances found: 8
#
#
# Sequence: 11
#
# No dist in frame 2 for left join 12
# No dist in frame 5 for left join 10
# No dist in frame 5 for left join 16
# No distances found: 3
#
#
# Sequence: 12
#
# No distances found: 0
#
#
# Sequence: 13
#
# No distances found: 0
#
#
# Sequence: 14
#
# No distances found: 0
#
#
# Sequence: 15
#
# No distances found: 0
#
#
# Sequence: 16
#
# No distances found: 0
#
#
# Sequence: 17
#
# No distances found: 0
#
#
# Sequence: 18
#
# No distances found: 0
#
#
# Sequence: 19
#
# No dist in frame 6 for left join 11
# No distances found: 1
#
#
# Sequence: 20
#
# No distances found: 0
#
#
# Sequence: 21
#
# No distances found: 0
#
#
# Sequence: 22
#
# No distances found: 0
#
#
# Sequence: 23
#
# No distances found: 0
#
#
# Sequence: 24
#
# No distances found: 0
#
#
# Sequence: 25
#
# No dist in frame 7 for left join 5
# No distances found: 1
#
#
# Sequence: 26
#
# No distances found: 0
#
#
# Sequence: 27
#
# No distances found: 0
#
#
# Sequence: 28
#
# No dist in frame 0 for left join 7
# No dist in frame 7 for left join 8
# No distances found: 2
#
#
# Sequence: 29
#
# No dist in frame 3 for left join 5
# No dist in frame 4 for left join 20
# No dist in frame 6 for left join 9
# No distances found: 3
#
#
# Sequence: 30
#
# No dist in frame 2 for left join 17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[96], line 59
#      55 distance_left = dist_joint_bbox(hand_poses_left[j], obj_center, faces)
#      56 # print("\nRight") # TODO
#      57 # print("Point:", hand_poses_right[j]) # TODO
#      58 # print("BBox", faces) # TODO
# ---> 59 distance_right = dist_joint_bbox(hand_poses_right[j], obj_center, faces)
#      60 # print("Distance:", distance_right) # TODO
#      62 if distance_left is None:
#
# Cell In[63], line 43, in dist_joint_bbox(joint, center, faces)
#      37 # debug print TODO
#      38 # print("Computing distance for a joint...")
#      39 # in_square_count = 0
#      41 for face in faces:
#      42     # compute the intersection point
# ---> 43     inter = line_plane_intersection(joint, center_vec, face)
#      45     # check if the intersection point is within the face
#      46     if inter is not None and is_pt_in_rect(inter, face):
#      47         # debug counter TODO
#      48         # in_square_count += 1
#      49
#      50         # compute the distance
#
# Cell In[81], line 24, in line_plane_intersection(line_pt, line_dir, plane_vertices)
#      21 assert plane_vertices.shape == (4,3)
#      23 plane_normal = np.cross(plane_vertices[1] - plane_vertices[0], plane_vertices[3] - plane_vertices[0])
# ---> 24 plane_norm = np.linalg.norm(plane_normal)
#      25 assert plane_norm > 1e-6
#      26 plane_normal /= plane_norm
#
# File ~/mambaforge/envs/3dv/lib/python3.11/site-packages/numpy/linalg/linalg.py:2534, in norm(x, ord, axis, keepdims)
#    2383 @array_function_dispatch(_norm_dispatcher)
#    2384 def norm(x, ord=None, axis=None, keepdims=False):
#    2385     """
#    2386     Matrix or vector norm.
#    2387
#    (...)
#    2532
#    2533     """
# -> 2534     x = asarray(x)
#    2536     if not issubclass(x.dtype.type, (inexact, object_)):
#    2537         x = x.astype(float)
#
# KeyboardInterrupt:

# %%
arr = np.array([1, 2, 3], dtype=np.double)
r = np.linalg.norm(arr)
print(type(r))
# Out:
# <class 'numpy.float64'>
